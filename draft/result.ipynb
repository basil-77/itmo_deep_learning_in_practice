# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
v8 = pd.read_csv('/Users/muzafarov/Desktop/MyEducation/DeepLearningInPractice/itmo_deep_learning_in_practice/tables/results_v8.csv')
v5su = pd.read_csv('/Users/muzafarov/Desktop/MyEducation/DeepLearningInPractice/itmo_deep_learning_in_practice/tables/results_v5su.csv')
v8n640 = pd.read_csv('/Users/muzafarov/Desktop/MyEducation/DeepLearningInPractice/itmo_deep_learning_in_practice/tables/results_v8n640.csv')
v8s640 = pd.read_csv('/Users/muzafarov/Desktop/MyEducation/DeepLearningInPractice/itmo_deep_learning_in_practice/tables/results_v8s640.csv')

# %%
v8
# Out:
#                       epoch           train/box_loss           train/cls_loss  \
# 0                         1                  1.15350                  4.49000
# 1                         2                  1.09830                  1.82230
# 2                         3                  1.09400                  1.08340
# 3                         4                  1.07700                  0.93864
# 4                         5                  1.04360                  0.84034
# 5                         6                  1.02210                  0.77796
# 6                         7                  1.00870                  0.74603
# 7                         8                  0.99470                  0.71271
# 8                         9                  0.98292                  0.68478
# 9                        10                  0.97493                  0.66843
# 10                       11                  0.97563                  0.65573
# ...

# %%
v8['   metrics/precision(B)'].iloc[19], v8['      metrics/recall(B)'].iloc[19], v8['       metrics/mAP50(B)'].iloc[19], v8['    metrics/mAP50-95(B)'].iloc[19]
# Out:
# (0.81094, 0.7301, 0.81824, 0.62838)

# %%
v5su['   metrics/precision(B)'].iloc[19], v5su['      metrics/recall(B)'].iloc[19], v5su['       metrics/mAP50(B)'].iloc[19], v5su['    metrics/mAP50-95(B)'].iloc[19]
# Out:
# (0.74297, 0.74024, 0.80417, 0.60305)

# %%
v8n640['   metrics/precision(B)'].iloc[19], v8n640['      metrics/recall(B)'].iloc[19], v8n640['       metrics/mAP50(B)'].iloc[19], v8n640['    metrics/mAP50-95(B)'].iloc[19]
# Out:
# (0.72414, 0.63267, 0.70368, 0.51832)

# %%
v8s640['   metrics/precision(B)'].iloc[19], v8s640['      metrics/recall(B)'].iloc[19], v8s640['       metrics/mAP50(B)'].iloc[19], v8s640['    metrics/mAP50-95(B)'].iloc[19]
# Out:
# (0.79494, 0.75753, 0.83163, 0.62737)

# %%
v5su
# Out:
#                       epoch           train/box_loss           train/cls_loss  \
# 0                         1                  1.22860                  2.77460
# 1                         2                  1.16440                  1.14670
# 2                         3                  1.17160                  1.05780
# 3                         4                  1.15360                  1.01020
# 4                         5                  1.09990                  0.90625
# 5                         6                  1.05970                  0.83939
# 6                         7                  1.03960                  0.79634
# 7                         8                  1.01590                  0.76132
# 8                         9                  0.99584                  0.72687
# 9                        10                  0.98310                  0.70710
# 10                       11                  0.97509                  0.69341
# ...

# %%
# Данные для первого источника
x_values1 = v5su['                  epoch']
y_values1 = v5su['   metrics/precision(B)']

# Данные для второго источника
x_values2 = v8['                  epoch']
y_values2 = v8['   metrics/precision(B)']

# Данные для третьего источника
x_values3 = v8n640['                  epoch']
y_values3 = v8n640['   metrics/precision(B)']

# Данные для четвертого источника
x_values4 = v8s640['                  epoch']
y_values4 = v8s640['   metrics/precision(B)']

# Построение линейного графика для первого источника
plt.plot(x_values1, y_values1, label='YOLOv5su', marker='o')

# Построение линейного графика для второго источника
plt.plot(x_values2, y_values2, label='YOLOv8', marker='o')

# Построение линейного графика для второго источника
plt.plot(x_values3, y_values3, label='YOLOv8n640', marker='o')

# Построение линейного графика для второго источника
plt.plot(x_values4, y_values4, label='YOLOv8s640', marker='o')

# Добавление заголовка и меток осей
plt.title('Сравнение моделей')
plt.xlabel('Количество эпох')
plt.ylabel('precision')

# Добавление легенды
plt.legend()

# Сохранение графика
plt.savefig('/Users/muzafarov/Desktop/MyEducation/DeepLearningInPractice/itmo_deep_learning_in_practice/img/precision.png', format='png')

# Отображение графика
plt.show()

# %%
# Данные для первого источника
x_values1 = v5su['                  epoch']
y_values1 = v5su['      metrics/recall(B)']

# Данные для второго источника
x_values2 = v8['                  epoch']
y_values2 = v8['      metrics/recall(B)']

# Данные для третьего источника
x_values3 = v8n640['                  epoch']
y_values3 = v8n640['      metrics/recall(B)']

# Данные для четвертого источника
x_values4 = v8s640['                  epoch']
y_values4 = v8s640['      metrics/recall(B)']

# Построение линейного графика для первого источника
plt.plot(x_values1, y_values1, label='YOLOv5su', marker='o')

# Построение линейного графика для второго источника
plt.plot(x_values2, y_values2, label='YOLOv8', marker='o')

# Построение линейного графика для второго источника
plt.plot(x_values3, y_values3, label='YOLOv8n640', marker='o')

# Построение линейного графика для второго источника
plt.plot(x_values4, y_values4, label='YOLOv8s640', marker='o')

# Добавление заголовка и меток осей
plt.title('Сравнение моделей')
plt.xlabel('Количество эпох')
plt.ylabel('recall')

# Добавление легенды
plt.legend()

# Сохранение графика
plt.savefig('/Users/muzafarov/Desktop/MyEducation/DeepLearningInPractice/itmo_deep_learning_in_practice/img/recall.png', format='png')

# Отображение графика
plt.show()

# %%
# Данные для первого источника
x_values1 = v5su['                  epoch']
y_values1 = v5su['       metrics/mAP50(B)']

# Данные для второго источника
x_values2 = v8['                  epoch']
y_values2 = v8['       metrics/mAP50(B)']

# Данные для третьего источника
x_values3 = v8n640['                  epoch']
y_values3 = v8n640['       metrics/mAP50(B)']

# Данные для четвертого источника
x_values4 = v8s640['                  epoch']
y_values4 = v8s640['       metrics/mAP50(B)']

# Построение линейного графика для первого источника
plt.plot(x_values1, y_values1, label='YOLOv5su', marker='o')

# Построение линейного графика для второго источника
plt.plot(x_values2, y_values2, label='YOLOv8', marker='o')

# Построение линейного графика для второго источника
plt.plot(x_values3, y_values3, label='YOLOv8n640', marker='o')

# Построение линейного графика для второго источника
plt.plot(x_values4, y_values4, label='YOLOv8s640', marker='o')

# Добавление заголовка и меток осей
plt.title('Сравнение моделей')
plt.xlabel('Количество эпох')
plt.ylabel('mAP50(B)')

# Добавление легенды
plt.legend()

# Сохранение графика
plt.savefig('/Users/muzafarov/Desktop/MyEducation/DeepLearningInPractice/itmo_deep_learning_in_practice/img/mAP.png', format='png')

# Отображение графика
plt.show()

# %%
# Данные для первого источника
x_values1 = v5su['                  epoch']
y_values1 = v5su['    metrics/mAP50-95(B)']

# Данные для второго источника
x_values2 = v8['                  epoch']
y_values2 = v8['    metrics/mAP50-95(B)']

# Данные для третьего источника
x_values3 = v8n640['                  epoch']
y_values3 = v8n640['    metrics/mAP50-95(B)']

# Данные для четвертого источника
x_values4 = v8s640['                  epoch']
y_values4 = v8s640['    metrics/mAP50-95(B)']

# Построение линейного графика для первого источника
plt.plot(x_values1, y_values1, label='YOLOv5su', marker='o')

# Построение линейного графика для второго источника
plt.plot(x_values2, y_values2, label='YOLOv8', marker='o')

# Построение линейного графика для второго источника
plt.plot(x_values3, y_values3, label='YOLOv8n640', marker='o')

# Построение линейного графика для второго источника
plt.plot(x_values4, y_values4, label='YOLOv8s640', marker='o')

# Добавление заголовка и меток осей
plt.title('Сравнение моделей')
plt.xlabel('Количество эпох')
plt.ylabel('mAP50-95(B)')

# Добавление легенды
plt.legend()

# Отображение графика
plt.show()
